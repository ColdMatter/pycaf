# %%
from pycaf import Experiment, PatternVisualizer
import matplotlib.pyplot as plt
import numpy as np
from time import sleep
import sys

sys.path.append("C:\\EDMSuite\\MoleculeMOTScripts")
sys.path.append("C:\\ControlPrograms\\EDMSuite\\MoleculeMOTScripts")
config_path = "C:\\ControlPrograms\\pycaf\\config_tweezer_analysis.json"
pattern_vis = PatternVisualizer(config_path=config_path)
expt = Experiment(config_path=config_path, interval=0.1)
expt.connect()
# texp = pyt.TweezerExperimentAnalysis(day='29',month='01Jan', year='2026')

# %%
expt.scan_motmaster_parameter("RbTweezerBasic2025_BackgroundSubtracted", "tScanCount", [0.0], iterations=1, save=False)
# Out:
# []
